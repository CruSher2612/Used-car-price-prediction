# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train-data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
df.shape
# Out:
# (6019, 14)

# %%
print(df['Owner_Type'].unique())
print(df['Fuel_Type'].unique())
print(df['Transmission'].unique())
#print(df['Owner'].unique())
# Out:
# ['First' 'Second' 'Fourth & Above' 'Third']
# ['CNG' 'Diesel' 'Petrol' 'LPG' 'Electric']
# ['Manual' 'Automatic']

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats        Price
# count  6019.000000  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   3009.000000  2013.358199       5.873838e+04     5.278735     9.479468
# std    1737.679967     3.269742       9.126884e+04     0.808840    11.187917
# min       0.000000  1998.000000       1.710000e+02     0.000000     0.440000
# 25%    1504.500000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3009.000000  2014.000000       5.300000e+04     5.000000     5.640000
# 75%    4513.500000  2016.000000       7.300000e+04     5.000000     9.950000
# max    6018.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
df.drop(["Unnamed: 0","New_Price"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df.isnull())
plt.show()

# %%
df['Location'].value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
df['Fuel_Type'].value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
df[(df['Fuel_Type']=='Electric') | (df['Fuel_Type']=='LPG')]
# Out:
#                                  Name   Location  Year  Kilometers_Driven  \
# 5     Hyundai EON LPG Era Plus Option  Hyderabad  2012              75000
# 936       Maruti Wagon R LXI LPG BSIV  Hyderabad  2012              72000
# 987      Maruti Wagon R LXI DUO BSIII     Mumbai  2008              64226
# 2278      Hyundai Santro Xing GLS LPG       Pune  2010              55000
# 2385      Hyundai Santro Xing GLS LPG  Hyderabad  2011              17000
# 2436            Hyundai i10 Magna LPG     Jaipur  2012              53000
# 2941  Hyundai Santro Xing GL Plus LPG  Hyderabad  2014              56000
# 3595      Maruti Wagon R LX DUO BSIII  Hyderabad  2007              65047
# 4446             Mahindra E Verito D4    Chennai  2016              50000
# 4904        Toyota Prius 2009-2016 Z4     Mumbai  2011              44000
# 5506      Maruti Wagon R Duo LX BSIII  Hyderabad  2012              72389
# 5997           Maruti Wagon R Duo Lxi     Jaipur  2010              70000
#
#      Fuel_Type Transmission Owner_Type      Mileage   Engine      Power  \
# 5          LPG       Manual      First   21.1 km/kg   814 CC   55.2 bhp
# 936        LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
# 987        LPG       Manual      First   17.3 km/kg  1061 CC   57.5 bhp
# 2278       LPG       Manual     Second  13.45 km/kg  1086 CC   62.1 bhp
# 2385       LPG       Manual      First  13.45 km/kg  1086 CC   62.1 bhp
# 2436       LPG       Manual     Second   19.2 km/kg  1086 CC  68.05 bhp
# 2941       LPG       Manual      First  13.45 km/kg  1086 CC   62.1 bhp
# 3595       LPG       Manual      First   17.3 km/kg  1061 CC   57.5 bhp
# 4446  Electric    Automatic      First          NaN    72 CC     41 bhp
# 4904  Electric    Automatic      First          NaN  1798 CC     73 bhp
# 5506       LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
# 5997       LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
#
#       Seats  Price
# 5       5.0   2.35
# 936     5.0   2.85
# 987     5.0   1.45
# 2278    5.0   1.65
# 2385    5.0   3.10
# 2436    5.0   2.85
# 2941    5.0   3.20
# 3595    5.0   1.95
# 4446    5.0  13.00
# 4904    5.0  12.75
# 5506    5.0   3.20
# 5997    5.0   2.27

# %%
df[(df['Fuel_Type']=='Electric')]
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type Mileage   Engine   Power  Seats  Price
# 4446    Automatic      First     NaN    72 CC  41 bhp    5.0  13.00
# 4904    Automatic      First     NaN  1798 CC  73 bhp    5.0  12.75

# %%
df.drop(df[(df['Fuel_Type']=='Electric')].index, axis=0, inplace = True)

# %%
df.drop(df[(df['Fuel_Type']=='LPG')].index, axis=0, inplace = True)

# %%
df['Transmission'].value_counts()
# Out:
# Manual       4289
# Automatic    1718
# Name: Transmission, dtype: int64

# %%
df['Owner_Type'].value_counts()
# Out:
# First             4919
# Second             966
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %%
df.drop(df[df['Owner_Type']=='Fourth & Above'].index, axis=0, inplace = True)

# %%
df['Seats'].value_counts()
# Out:
# 5.0     4998
# 7.0      672
# 8.0      132
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
df.drop(df[df['Seats']>8].index, axis=0, inplace = True)

# %%
df['Seats'].value_counts()
# Out:
# 5.0    4998
# 7.0     672
# 8.0     132
# 4.0      99
# 6.0      31
# 2.0      16
# 0.0       1
# Name: Seats, dtype: int64

# %%
df.drop(df[df['Seats']==0].index, axis=0, inplace = True)

# %%
df['Seats'].value_counts()
# Out:
# 5.0    4998
# 7.0     672
# 8.0     132
# 4.0      99
# 6.0      31
# 2.0      16
# Name: Seats, dtype: int64

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5989 rows x 12 columns]

# %%
df['Car']=df['Name'].map(lambda x: str(x).strip().split(" ")[0])

# %%
df['Model']=df['Name'].map(lambda x: str(x).strip().split(" ")[1])

# %%
df['Model_1']=df['Name'].map(lambda x: str(x).strip().split(" ")[2])

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price        Car   Model Model_1
# 0      1.75     Maruti   Wagon       R
# 1     12.50    Hyundai   Creta     1.6
# 2      4.50      Honda    Jazz       V
# 3      6.00     Maruti  Ertiga     VDI
# 4     17.74       Audi      A4     New
# ...     ...        ...     ...     ...
# 6014   4.75     Maruti   Swift     VDI
# 6015   4.00    Hyundai   Xcent     1.1
# 6016   2.90   Mahindra    Xylo      D4
# 6017   2.65     Maruti   Wagon       R
# 6018   2.50  Chevrolet    Beat  Diesel
#
# [5989 rows x 15 columns]

# %%
df['Car'] = df['Model'].astype(str) + " " + df['Model_1']

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price          Car   Model Model_1
# 0      1.75      Wagon R   Wagon       R
# 1     12.50    Creta 1.6   Creta     1.6
# 2      4.50       Jazz V    Jazz       V
# 3      6.00   Ertiga VDI  Ertiga     VDI
# 4     17.74       A4 New      A4     New
# ...     ...          ...     ...     ...
# 6014   4.75    Swift VDI   Swift     VDI
# 6015   4.00    Xcent 1.1   Xcent     1.1
# 6016   2.90      Xylo D4    Xylo      D4
# 6017   2.65      Wagon R   Wagon       R
# 6018   2.50  Beat Diesel    Beat  Diesel
#
# [5989 rows x 15 columns]

# %%
df.drop(['Model','Model_1'],axis=1,inplace=True)

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price          Car
# 0      1.75      Wagon R
# 1     12.50    Creta 1.6
# 2      4.50       Jazz V
# 3      6.00   Ertiga VDI
# 4     17.74       A4 New
# ...     ...          ...
# 6014   4.75    Swift VDI
# 6015   4.00    Xcent 1.1
# 6016   2.90      Xylo D4
# 6017   2.65      Wagon R
# 6018   2.50  Beat Diesel
#
# [5989 rows x 13 columns]

# %%
df['Name']=df['Name'].map(lambda x: str(x).strip().split(" ")[0])

# %%
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type     Mileage   Engine      Power  Seats  Price          Car
# 0         First  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75      Wagon R
# 1         First  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50    Creta 1.6
# 2         First   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50       Jazz V
# 3         First  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00   Ertiga VDI
# 4        Second   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74       A4 New
# ...         ...         ...      ...        ...    ...    ...          ...
# 6014      First   28.4 kmpl  1248 CC     74 bhp    5.0   4.75    Swift VDI
# 6015      First   24.4 kmpl  1120 CC     71 bhp    5.0   4.00    Xcent 1.1
# 6016     Second   14.0 kmpl  2498 CC    112 bhp    8.0   2.90      Xylo D4
# 6017      First   18.9 kmpl   998 CC   67.1 bhp    5.0   2.65      Wagon R
# 6018      First  25.44 kmpl   936 CC   57.6 bhp    5.0   2.50  Beat Diesel
#
# [5989 rows x 13 columns]

# %%
df = df[['Name','Car','Location','Year','Kilometers_Driven','Fuel_Type','Transmission','Owner_Type','Mileage','Engine', 'Power','Seats','Price']]

# %%
df
# Out:
#            Name          Car    Location  Year  Kilometers_Driven Fuel_Type  \
# 0        Maruti      Wagon R      Mumbai  2010              72000       CNG
# 1       Hyundai    Creta 1.6        Pune  2015              41000    Diesel
# 2         Honda       Jazz V     Chennai  2011              46000    Petrol
# 3        Maruti   Ertiga VDI     Chennai  2012              87000    Diesel
# 4          Audi       A4 New  Coimbatore  2013              40670    Diesel
# ...         ...          ...         ...   ...                ...       ...
# 6014     Maruti    Swift VDI       Delhi  2014              27365    Diesel
# 6015    Hyundai    Xcent 1.1      Jaipur  2015             100000    Diesel
# 6016   Mahindra      Xylo D4      Jaipur  2012              55000    Diesel
# 6017     Maruti      Wagon R     Kolkata  2013              46000    Petrol
# 6018  Chevrolet  Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type     Mileage   Engine      Power  Seats  Price
# 0          Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75
# 1          Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50
# 2          Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50
# 3          Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00
# 4       Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74
# ...           ...        ...         ...      ...        ...    ...    ...
# 6014       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0   4.75
# 6015       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0   4.00
# 6016       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0   2.90
# 6017       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0   2.65
# 6018       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0   2.50
#
# [5989 rows x 13 columns]

# %%
df['Year'].value_counts()
# Out:
# 2014    796
# 2015    743
# 2016    739
# 2013    648
# 2017    587
# 2012    574
# 2011    464
# 2010    339
# 2018    298
# 2009    197
# 2008    171
# 2007    121
# 2019    102
# 2006     77
# 2005     56
# 2004     29
# 2003     17
# 2002     14
# 2001      7
# 1998      4
# 2000      4
# 1999      2
# Name: Year, dtype: int64

# %%
df['Year']=df['Year'].astype(str)

# %%
df['Year']=np.where(df['Year'].astype(int)<2001,"less than 2001",df['Year'])

# %%
df['Year'].value_counts()
# Out:
# 2014              796
# 2015              743
# 2016              739
# 2013              648
# 2017              587
# 2012              574
# 2011              464
# 2010              339
# 2018              298
# 2009              197
# 2008              171
# 2007              121
# 2019              102
# 2006               77
# 2005               56
# 2004               29
# 2003               17
# 2002               14
# less than 2001     10
# 2001                7
# Name: Year, dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                  0
# Car                   0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine               35
# Power                35
# Seats                41
# Price                 0
# dtype: int64

# %%
df['Mileage'].unique
# Out:
# <bound method Series.unique of 0       26.6 km/kg
# 1       19.67 kmpl
# 2        18.2 kmpl
# 3       20.77 kmpl
# 4        15.2 kmpl
#            ...
# 6014     28.4 kmpl
# 6015     24.4 kmpl
# 6016     14.0 kmpl
# 6017     18.9 kmpl
# 6018    25.44 kmpl
# Name: Mileage, Length: 5989, dtype: object>

# %%
df['Mileage']=df['Mileage'].map(lambda x: str(x).strip().split(" ")[0])

# %%
df['Mileage']=df['Mileage'].astype(float)

# %%
df['Mileage'].unique
# Out:
# <bound method Series.unique of 0       26.60
# 1       19.67
# 2       18.20
# 3       20.77
# 4       15.20
#         ...
# 6014    28.40
# 6015    24.40
# 6016    14.00
# 6017    18.90
# 6018    25.44
# Name: Mileage, Length: 5989, dtype: float64>

# %%
df1 = df[df.isna().any(axis=1)]

# %%
df1
# Out:
#          Name                  Car    Location  Year  Kilometers_Driven  \
# 194     Honda             City 1.5   Ahmedabad  2007              60006
# 208    Maruti            Swift 1.3     Kolkata  2010              42001
# 229      Ford          Figo Diesel   Bangalore  2015              70436
# 733    Maruti            Swift 1.3     Chennai  2006              97800
# 749      Land          Rover Range      Mumbai  2008              55001
# 1294    Honda             City 1.3       Delhi  2009              55005
# 1327   Maruti            Swift 1.3   Hyderabad  2015              50295
# 1385    Honda             City 1.5        Pune  2004             115000
# 1460     Land          Rover Range  Coimbatore  2008              69078
# 1917    Honda             City 1.5      Jaipur  2005              88000
# 2074   Maruti            Swift 1.3        Pune  2011              24255
# 2096  Hyundai            Santro LP  Coimbatore  2004              52146
# 2264   Toyota           Etios Liva        Pune  2012              24500
# 2325   Maruti            Swift 1.3        Pune  2015              67000
# 2335   Maruti            Swift 1.3      Mumbai  2007              55000
# 2369   Maruti           Estilo LXI     Chennai  2008              56000
# 2530      BMW             5 Series       Kochi  2014              64158
# 2542  Hyundai           Santro GLS   Bangalore  2011              65000
# 2623      BMW             5 Series        Pune  2012              95000
# 2668   Maruti            Swift 1.3     Kolkata  2014              32986
# 2737   Maruti              Wagon R      Jaipur  2001             200000
# 2780  Hyundai           Santro GLS        Pune  2009             100000
# 2842  Hyundai           Santro GLS   Bangalore  2012              43000
# 3272      BMW             5 Series      Mumbai  2008              81000
# 3520      BMW             5 Series       Delhi  2012              90000
# 3522  Hyundai           Santro GLS       Kochi  2012              66400
# 3800     Ford  Endeavour Hurricane      Mumbai  2012             129000
# 3810    Honda              CR-V AT     Kolkata  2013              27000
# 3882   Maruti           Estilo LXI     Kolkata  2010              40000
# 4011     Fiat            Punto 1.3        Pune  2011              45271
# 4152     Land          Rover Range      Mumbai  2003              75000
# 4229  Hyundai          Santro Xing   Bangalore  2005              79000
# 4577      BMW             5 Series       Delhi  2012              72000
# 4604    Honda          Jazz Select        Pune  2011              98000
# 4697     Fiat            Punto 1.2       Kochi  2017              17941
# 4712  Hyundai          Santro Xing        Pune  2003              80000
# 4952     Fiat            Punto 1.4     Kolkata  2010              47000
# 5015   Maruti            Swift 1.3       Delhi  2006              63000
# 5185   Maruti            Swift 1.3       Delhi  2012              52000
# 5270    Honda             City 1.5   Bangalore  2002              53000
# 5893   Maruti           Estilo LXI     Chennai  2008              51000
#
#      Fuel_Type Transmission Owner_Type  Mileage   Engine     Power  Seats  \
# 194     Petrol       Manual      First     0.00      NaN       NaN    NaN
# 208     Petrol       Manual      First    16.10      NaN       NaN    NaN
# 229     Diesel       Manual      First     0.00  1498 CC    99 bhp    NaN
# 733     Petrol       Manual      Third    16.10      NaN       NaN    NaN
# 749     Diesel    Automatic     Second     0.00      NaN       NaN    NaN
# 1294    Petrol       Manual      First    12.80      NaN       NaN    NaN
# 1327    Petrol       Manual      First    16.10      NaN       NaN    NaN
# 1385    Petrol       Manual     Second     0.00      NaN       NaN    NaN
# 1460    Petrol       Manual      First     0.00      NaN       NaN    NaN
# 1917    Petrol       Manual     Second    13.00  1493 CC   100 bhp    NaN
# 2074    Petrol       Manual      First    16.10      NaN       NaN    NaN
# 2096    Petrol       Manual      First     0.00      NaN       NaN    NaN
# 2264    Petrol       Manual     Second    18.30      NaN       NaN    NaN
# 2325    Petrol       Manual      First    16.10      NaN       NaN    NaN
# 2335    Petrol       Manual     Second    16.10      NaN       NaN    NaN
# 2369    Petrol       Manual     Second    19.50  1061 CC  null bhp    NaN
# 2530    Diesel    Automatic      First    18.48      NaN       NaN    NaN
# 2542    Petrol       Manual     Second     0.00      NaN       NaN    NaN
# 2623    Diesel    Automatic     Second    18.48      NaN       NaN    NaN
# 2668    Petrol       Manual      First    16.10      NaN       NaN    NaN
# 2737    Petrol       Manual      First    12.00      NaN       NaN    NaN
# 2780    Petrol       Manual      First     0.00      NaN       NaN    NaN
# 2842    Petrol       Manual      First     0.00      NaN       NaN    NaN
# 3272    Diesel    Automatic     Second    18.48      NaN       NaN    NaN
# 3520    Diesel    Automatic      First    18.48      NaN       NaN    NaN
# 3522    Petrol       Manual      First     0.00      NaN       NaN    NaN
# 3800    Diesel    Automatic      First    12.80  2953 CC  null bhp    NaN
# 3810    Petrol    Automatic      First    14.00      NaN       NaN    NaN
# 3882    Petrol       Manual     Second    19.50  1061 CC  null bhp    NaN
# 4011    Diesel       Manual      First    20.30      NaN       NaN    NaN
# 4152    Diesel    Automatic     Second     0.00      NaN       NaN    NaN
# 4229    Petrol       Manual     Second    17.00      NaN       NaN    NaN
# 4577    Diesel    Automatic      Third    18.48      NaN       NaN    NaN
# 4604    Petrol       Manual      First    16.70      NaN       NaN    NaN
# 4697    Petrol       Manual      First    15.70      NaN       NaN    NaN
# 4712    Petrol       Manual     Second    17.00      NaN       NaN    NaN
# 4952    Petrol       Manual      First    14.60      NaN       NaN    NaN
# 5015    Petrol       Manual      First    16.10      NaN       NaN    NaN
# 5185    Petrol       Manual      First    16.10      NaN       NaN    NaN
# 5270    Petrol       Manual     Second     0.00      NaN       NaN    NaN
# 5893    Petrol       Manual     Second    19.50  1061 CC  null bhp    NaN
#
#       Price
# 194    2.95
# 208    2.11
# 229    3.60
# 733    1.75
# 749   26.50
# 1294   3.20
# 1327   5.80
# 1385   1.50
# 1460  40.88
# 1917   1.70
# 2074   3.15
# 2096   1.93
# 2264   2.95
# 2325   4.70
# 2335   1.75
# 2369   1.50
# 2530  17.89
# 2542   3.15
# 2623  18.00
# 2668   4.24
# 2737   0.70
# 2780   1.60
# 2842   3.25
# 3272  10.50
# 3520  14.50
# 3522   2.66
# 3800   7.00
# 3810  11.99
# 3882   2.50
# 4011   2.60
# 4152  16.11
# 4229   1.65
# 4577  13.85
# 4604   3.15
# 4697   3.93
# 4712   0.90
# 4952   1.49
# 5015   1.60
# 5185   3.65
# 5270   1.85
# 5893   1.75

# %%
df['Engine'] = df['Engine'].fillna(0)

# %%
df['Power'] = df['Power'].fillna(0)

# %%
df['Seats'] = df['Seats'].fillna(0)

# %%
df['Power'] = df['Power'].replace("null bhp", 0)

# %%
df
# Out:
#            Name          Car    Location  Year  Kilometers_Driven Fuel_Type  \
# 0        Maruti      Wagon R      Mumbai  2010              72000       CNG
# 1       Hyundai    Creta 1.6        Pune  2015              41000    Diesel
# 2         Honda       Jazz V     Chennai  2011              46000    Petrol
# 3        Maruti   Ertiga VDI     Chennai  2012              87000    Diesel
# 4          Audi       A4 New  Coimbatore  2013              40670    Diesel
# ...         ...          ...         ...   ...                ...       ...
# 6014     Maruti    Swift VDI       Delhi  2014              27365    Diesel
# 6015    Hyundai    Xcent 1.1      Jaipur  2015             100000    Diesel
# 6016   Mahindra      Xylo D4      Jaipur  2012              55000    Diesel
# 6017     Maruti      Wagon R     Kolkata  2013              46000    Petrol
# 6018  Chevrolet  Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type  Mileage   Engine      Power  Seats  Price
# 0          Manual      First    26.60   998 CC  58.16 bhp    5.0   1.75
# 1          Manual      First    19.67  1582 CC  126.2 bhp    5.0  12.50
# 2          Manual      First    18.20  1199 CC   88.7 bhp    5.0   4.50
# 3          Manual      First    20.77  1248 CC  88.76 bhp    7.0   6.00
# 4       Automatic     Second    15.20  1968 CC  140.8 bhp    5.0  17.74
# ...           ...        ...      ...      ...        ...    ...    ...
# 6014       Manual      First    28.40  1248 CC     74 bhp    5.0   4.75
# 6015       Manual      First    24.40  1120 CC     71 bhp    5.0   4.00
# 6016       Manual     Second    14.00  2498 CC    112 bhp    8.0   2.90
# 6017       Manual      First    18.90   998 CC   67.1 bhp    5.0   2.65
# 6018       Manual      First    25.44   936 CC   57.6 bhp    5.0   2.50
#
# [5989 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Name                 0
# Car                  0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df
# Out:
#            Name          Car    Location  Year  Kilometers_Driven Fuel_Type  \
# 0        Maruti      Wagon R      Mumbai  2010              72000       CNG
# 1       Hyundai    Creta 1.6        Pune  2015              41000    Diesel
# 2         Honda       Jazz V     Chennai  2011              46000    Petrol
# 3        Maruti   Ertiga VDI     Chennai  2012              87000    Diesel
# 4          Audi       A4 New  Coimbatore  2013              40670    Diesel
# ...         ...          ...         ...   ...                ...       ...
# 6014     Maruti    Swift VDI       Delhi  2014              27365    Diesel
# 6015    Hyundai    Xcent 1.1      Jaipur  2015             100000    Diesel
# 6016   Mahindra      Xylo D4      Jaipur  2012              55000    Diesel
# 6017     Maruti      Wagon R     Kolkata  2013              46000    Petrol
# 6018  Chevrolet  Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type  Mileage   Engine      Power  Seats  Price
# 0          Manual      First    26.60   998 CC  58.16 bhp    5.0   1.75
# 1          Manual      First    19.67  1582 CC  126.2 bhp    5.0  12.50
# 2          Manual      First    18.20  1199 CC   88.7 bhp    5.0   4.50
# 3          Manual      First    20.77  1248 CC  88.76 bhp    7.0   6.00
# 4       Automatic     Second    15.20  1968 CC  140.8 bhp    5.0  17.74
# ...           ...        ...      ...      ...        ...    ...    ...
# 6014       Manual      First    28.40  1248 CC     74 bhp    5.0   4.75
# 6015       Manual      First    24.40  1120 CC     71 bhp    5.0   4.00
# 6016       Manual     Second    14.00  2498 CC    112 bhp    8.0   2.90
# 6017       Manual      First    18.90   998 CC   67.1 bhp    5.0   2.65
# 6018       Manual      First    25.44   936 CC   57.6 bhp    5.0   2.50
#
# [5989 rows x 13 columns]

# %%
df['Engine']=df['Engine'].map(lambda x: str(x).strip().split(" ")[0])

# %%
df['Power']=df['Power'].map(lambda x: str(x).strip().split(" ")[0])

# %%
df
# Out:
#            Name          Car    Location  Year  Kilometers_Driven Fuel_Type  \
# 0        Maruti      Wagon R      Mumbai  2010              72000       CNG
# 1       Hyundai    Creta 1.6        Pune  2015              41000    Diesel
# 2         Honda       Jazz V     Chennai  2011              46000    Petrol
# 3        Maruti   Ertiga VDI     Chennai  2012              87000    Diesel
# 4          Audi       A4 New  Coimbatore  2013              40670    Diesel
# ...         ...          ...         ...   ...                ...       ...
# 6014     Maruti    Swift VDI       Delhi  2014              27365    Diesel
# 6015    Hyundai    Xcent 1.1      Jaipur  2015             100000    Diesel
# 6016   Mahindra      Xylo D4      Jaipur  2012              55000    Diesel
# 6017     Maruti      Wagon R     Kolkata  2013              46000    Petrol
# 6018  Chevrolet  Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type  Mileage Engine  Power  Seats  Price
# 0          Manual      First    26.60    998  58.16    5.0   1.75
# 1          Manual      First    19.67   1582  126.2    5.0  12.50
# 2          Manual      First    18.20   1199   88.7    5.0   4.50
# 3          Manual      First    20.77   1248  88.76    7.0   6.00
# 4       Automatic     Second    15.20   1968  140.8    5.0  17.74
# ...           ...        ...      ...    ...    ...    ...    ...
# 6014       Manual      First    28.40   1248     74    5.0   4.75
# 6015       Manual      First    24.40   1120     71    5.0   4.00
# 6016       Manual     Second    14.00   2498    112    8.0   2.90
# 6017       Manual      First    18.90    998   67.1    5.0   2.65
# 6018       Manual      First    25.44    936   57.6    5.0   2.50
#
# [5989 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Name                 0
# Car                  0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.dtypes
# Out:
# Name                  object
# Car                   object
# Location              object
# Year                  object
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
df
# Out:
#            Name          Car    Location  Year  Kilometers_Driven Fuel_Type  \
# 0        Maruti      Wagon R      Mumbai  2010              72000       CNG
# 1       Hyundai    Creta 1.6        Pune  2015              41000    Diesel
# 2         Honda       Jazz V     Chennai  2011              46000    Petrol
# 3        Maruti   Ertiga VDI     Chennai  2012              87000    Diesel
# 4          Audi       A4 New  Coimbatore  2013              40670    Diesel
# ...         ...          ...         ...   ...                ...       ...
# 6014     Maruti    Swift VDI       Delhi  2014              27365    Diesel
# 6015    Hyundai    Xcent 1.1      Jaipur  2015             100000    Diesel
# 6016   Mahindra      Xylo D4      Jaipur  2012              55000    Diesel
# 6017     Maruti      Wagon R     Kolkata  2013              46000    Petrol
# 6018  Chevrolet  Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type  Mileage Engine  Power  Seats  Price
# 0          Manual      First    26.60    998  58.16    5.0   1.75
# 1          Manual      First    19.67   1582  126.2    5.0  12.50
# 2          Manual      First    18.20   1199   88.7    5.0   4.50
# 3          Manual      First    20.77   1248  88.76    7.0   6.00
# 4       Automatic     Second    15.20   1968  140.8    5.0  17.74
# ...           ...        ...      ...    ...    ...    ...    ...
# 6014       Manual      First    28.40   1248     74    5.0   4.75
# 6015       Manual      First    24.40   1120     71    5.0   4.00
# 6016       Manual     Second    14.00   2498    112    8.0   2.90
# 6017       Manual      First    18.90    998   67.1    5.0   2.65
# 6018       Manual      First    25.44    936   57.6    5.0   2.50
#
# [5989 rows x 13 columns]

# %%
df['Engine']=df['Engine'].astype('float64')

# %%
df['Power']=df['Power'].astype('float64')

# %%
#a.astype('float64', raise_on_error = False)

# %%
df.dtypes
# Out:
# Name                  object
# Car                   object
# Location              object
# Year                  object
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# dtype: object

# %%
car_list = df['Name'].unique()

# %%
car_list
# Out:
# array(['Maruti', 'Hyundai', 'Honda', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Smart', 'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley',
#        'Lamborghini'], dtype=object)

# %%
for i in car_list:
    df_honda = df.loc[df['Name'] == i]
    df_mean_m = round(df_honda['Mileage'].mean())
    if df['Name'].any()==i:
        df['Mileage']= df['Mileage'].replace(0.0, df_mean_m)
    print(f'{i} {df_mean_m}')
# Out:
# Maruti 22
# Hyundai 19
# Honda 19
# Audi 15
# Nissan 19
# Toyota 14
# Volkswagen 18
# Tata 20
# Land 14
# Mitsubishi 12
# Renault 21
# Mercedes-Benz 15
# BMW 17
# Mahindra 15
# Ford 19
# Porsche 14
# Datsun 22
# Jaguar 15
# Volvo 15
# Chevrolet 18
# Skoda 17
# Mini 19
# Fiat 18
# Jeep 17
# Smart 22
# Ambassador 13
# Isuzu 14
# ISUZU 12
# Force 17
# Bentley 9
# Lamborghini 6

# %%
#means = df['Mileage'].mean()

# %%
#df['Mileage']=df['Mileage'].replace(0.0, means)

# %%
column = df['Mileage'] 
count = column[column == 0].count()
print(count)
# Out:
# 0

# %%
df.loc[df['Mileage'] == 0]
# Out:
# Empty DataFrame
# Columns: [Name, Car, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, Price]
# Index: []

# %%
column = df['Engine'] 
count = column[column == 0].count()
print(count)
# Out:
# 35

# %%
#for i in car_list:
#    df_honda = df.loc[df['Name'] == i]
#    df['Mileage']=df['Mileage'].replace(0,df['Mileage'].mean())

# %%
for i in car_list:
    df_honda = df.loc[df['Name'] == i]
    df_mean_e = round(df_honda['Engine'].mean())
    if df['Name'].any()==i:
        df['Engine']= df['Engine'].replace(0.0, df_mean_e)
    print(f'{i} {round(df_mean_e)}')
# Out:
# Maruti 1140
# Hyundai 1307
# Honda 1499
# Audi 2278
# Nissan 1462
# Toyota 2308
# Volkswagen 1442
# Tata 1346
# Land 2409
# Mitsubishi 2537
# Renault 1310
# Mercedes-Benz 2372
# BMW 2301
# Mahindra 2133
# Ford 1596
# Porsche 3480
# Datsun 983
# Jaguar 2623
# Volvo 2160
# Chevrolet 1345
# Skoda 1786
# Mini 1767
# Fiat 1254
# Jeep 1917
# Smart 799
# Ambassador 1489
# Isuzu 2999
# ISUZU 2499
# Force 2183
# Bentley 5998
# Lamborghini 5204

# %%
column = df['Engine'] 
count = column[column == 0].count()
print(count)
# Out:
# 0

# %%
column = df['Power'] 
count = column[column == 0].count()
print(count)
# Out:
# 139

# %%
for i in car_list:
    df_honda = df.loc[df['Name'] == i]
    df_mean_p = df_honda['Power'].mean()
    if df['Name'].any()==i:
        df['Power']= df['Power'].replace(0.0, df_mean_p)
    print(f'{i} {round(df_mean_p)}')
# Out:
# Maruti 72
# Hyundai 91
# Honda 108
# Audi 192
# Nissan 88
# Toyota 127
# Volkswagen 95
# Tata 79
# Land 184
# Mitsubishi 140
# Renault 87
# Mercedes-Benz 193
# BMW 207
# Mahindra 121
# Ford 96
# Porsche 302
# Datsun 60
# Jaguar 239
# Volvo 187
# Chevrolet 91
# Skoda 126
# Mini 147
# Fiat 84
# Jeep 169
# Smart 72
# Ambassador 36
# Isuzu 175
# ISUZU 134
# Force 139
# Bentley 552
# Lamborghini 560

# %%
column = df['Power'] 
count = column[column == 0].count()
print(count)
# Out:
# 0

# %%
column = df['Seats'] 
count = column[column == 0].count()
print(count)
# Out:
# 41

# %%
for i in car_list:
    df_honda = df.loc[df['Name'] == i]
    df_mean_s = df_honda['Seats'].mean()
    if df['Name'].any()==i:
        df['Seats']= df['Seats'].replace(0.0, df_mean_s)
    print(f'{i} {round(df_mean_s)}')
# Out:
# Maruti 5
# Hyundai 5
# Honda 5
# Audi 5
# Nissan 5
# Toyota 6
# Volkswagen 5
# Tata 5
# Land 5
# Mitsubishi 6
# Renault 5
# Mercedes-Benz 5
# BMW 5
# Mahindra 7
# Ford 5
# Porsche 4
# Datsun 5
# Jaguar 5
# Volvo 5
# Chevrolet 5
# Skoda 5
# Mini 4
# Fiat 5
# Jeep 5
# Smart 2
# Ambassador 5
# Isuzu 7
# ISUZU 5
# Force 7
# Bentley 4
# Lamborghini 2

# %%
column = df['Seats'] 
count = column[column == 0].count()
print(count)
# Out:
# 0

# %%
df
# Out:
#            Name          Car    Location  Year  Kilometers_Driven Fuel_Type  \
# 0        Maruti      Wagon R      Mumbai  2010              72000       CNG
# 1       Hyundai    Creta 1.6        Pune  2015              41000    Diesel
# 2         Honda       Jazz V     Chennai  2011              46000    Petrol
# 3        Maruti   Ertiga VDI     Chennai  2012              87000    Diesel
# 4          Audi       A4 New  Coimbatore  2013              40670    Diesel
# ...         ...          ...         ...   ...                ...       ...
# 6014     Maruti    Swift VDI       Delhi  2014              27365    Diesel
# 6015    Hyundai    Xcent 1.1      Jaipur  2015             100000    Diesel
# 6016   Mahindra      Xylo D4      Jaipur  2012              55000    Diesel
# 6017     Maruti      Wagon R     Kolkata  2013              46000    Petrol
# 6018  Chevrolet  Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type  Mileage  Engine   Power  Seats  Price
# 0          Manual      First    26.60   998.0   58.16    5.0   1.75
# 1          Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2          Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3          Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4       Automatic     Second    15.20  1968.0  140.80    5.0  17.74
# ...           ...        ...      ...     ...     ...    ...    ...
# 6014       Manual      First    28.40  1248.0   74.00    5.0   4.75
# 6015       Manual      First    24.40  1120.0   71.00    5.0   4.00
# 6016       Manual     Second    14.00  2498.0  112.00    8.0   2.90
# 6017       Manual      First    18.90   998.0   67.10    5.0   2.65
# 6018       Manual      First    25.44   936.0   57.60    5.0   2.50
#
# [5989 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Name                 0
# Car                  0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.dtypes
# Out:
# Name                  object
# Car                   object
# Location              object
# Year                  object
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# dtype: object

# %%
plt.figure(figsize=(12,10))
most_cat = df['Name'].value_counts()
sns.barplot(x=most_cat, y=most_cat.index, data=df)
plt.xticks(size=15)
plt.xlabel("Frequency",size=22,c="g")
plt.ylabel("Manufactures",size=22,c="g")
plt.title("Total Cars of all Companies",size=28,c="r")
plt.show()

# %%
df['Name'].value_counts()[df['Name'].value_counts()<5]
# Out:
# Force          3
# ISUZU          2
# Smart          1
# Isuzu          1
# Ambassador     1
# Lamborghini    1
# Bentley        1
# Name: Name, dtype: int64

# %%
i = df['Name'].value_counts()[df['Name'].value_counts()<5].index
index = df[df['Name'].isin(i)].index
df.drop(index,axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
most_cat = df['Location'].value_counts()
sns.barplot(x=most_cat, y=most_cat.index, data=df)
plt.xticks(size=15)
plt.xlabel("Frequency",size=15,c="g")
plt.ylabel("Location",size=15,c="g")
plt.title("Total Cars Location wise",size=22,c="r")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df,y="Name",x="Price")
plt.xlabel("Price",size=18,c="g")
plt.ylabel("Manufactures",size=18,c="g")
plt.title("Price range of differents manufactures",size=25,c="r")
plt.xticks(rotation='vertical',size=15)
plt.show()

# %%
plt.figure(figsize=(12,8)) 
sns.scatterplot(data=df,y="Name",x='Price',color="m")
plt.xticks(rotation='vertical',size=15)
plt.xlabel("Rating",size=15,c="r")
plt.ylabel("Category",size=15,c="r")
plt.title("All Categ with their Rating",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df,x="Fuel_Type",y="Price")
plt.xlabel("Fuel Types",size=17,c="k")
plt.ylabel("Price",size=17,c="k")
plt.title("Fuel Types",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df,x="Year",y="Price")
plt.xlabel("Year",size=20,c="g")
plt.ylabel("Price",size=20,c="g")
plt.title("Year vs Price",size=25,c="r")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="Seats")
plt.xlabel("Seats",size=18,c="g")
plt.ylabel("Frequency",size=18,c="g")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.countplot(data=df,x="Owner_Type")
plt.xlabel("Owner Type",size=15,c="r")
plt.ylabel("Frequency",size=15,c="r")
plt.subplot(1,2,2)
labels =df['Owner_Type'].value_counts(sort = True).index
sizes = df['Owner_Type'].value_counts(sort = True)
plt.pie(sizes, labels=labels,autopct='%1.1f%%', shadow=True, startangle=270)
plt.title('Total % of Owner',size = 25,c="r")
plt.show()

# %%
df.describe()
# Out:
#        Kilometers_Driven      Mileage       Engine        Power        Seats  \
# count       5.979000e+03  5979.000000  5979.000000  5979.000000  5979.000000
# mean        5.858316e+04    18.401030  1615.983609   112.286528     5.272083
# std         9.142361e+04     4.160489   595.133553    53.052922     0.783820
# min         1.710000e+02     7.500000   624.000000    34.200000     2.000000
# 25%         3.392300e+04    15.400000  1197.000000    74.000000     5.000000
# 50%         5.300000e+04    18.480000  1493.000000    91.200000     5.000000
# 75%         7.300000e+04    21.140000  1968.000000   138.030000     5.000000
# max         6.500000e+06    33.540000  5461.000000   550.000000     8.000000
#
#              Price
# count  5979.000000
# mean      9.477938
# std      11.104630
# min       0.440000
# 25%       3.500000
# 50%       5.650000
# 75%       9.975000
# max     160.000000

# %%
col = ['Kilometers_Driven','Power','Mileage','Engine'] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.boxplot(x=v, data=df,color='red')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Power
# 2 Mileage
# 3 Engine

# %%
df.drop(df[df['Kilometers_Driven']>300000].index,inplace=True,axis=0)

# %%
df.drop(df[df['Power']>480].index,inplace=True,axis=0)

# %%
#df.drop(df[df['Mileage']<5].index,inplace=True,axis=0)
#df.drop(df[df['Engine']>5000].index,inplace=True,axis=0)

# %%
col = ['Kilometers_Driven','Power','Mileage','Engine'] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.boxplot(x=v, data=df,color='green')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Power
# 2 Mileage
# 3 Engine

# %%
df.shape
# Out:
# (5968, 13)

# %%
plt.figure(figsize=(11,7))
plt.subplot(1,1,1)
sns.distplot(df['Price'],color='r',kde_kws={'linewidth':3,'color':'b'});
plt.show()

# %%
col = ['Kilometers_Driven','Mileage','Engine',"Price"] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.distplot(x=df[v],color='g')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Mileage
# 2 Engine
# 3 Price

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,y="Price",x='Location',hue='Fuel_Type')
plt.xlabel("Location",size=15,c="r")
plt.ylabel("Price",size=15,c="r")
plt.title("Effect of fuel type on Car price for location",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.barplot(data=df,y="Price",x='Name',hue='Fuel_Type')
plt.xlabel("Location",size=15,c="r")
plt.ylabel("Price",size=15,c="r")
plt.xticks(rotation="vertical",size=10)
plt.title("Effect of fuel type on Price of differents brands",size=25,c="red")
plt.show()

# %%
col = ['Kilometers_Driven','Mileage','Engine',"Power"] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.scatterplot(x=df[v],y=df['Price'],color='purple')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Mileage
# 2 Engine
# 3 Power

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,y="Price",x='Location',hue='Owner_Type')
plt.xlabel("Location",size=15,c="red")
plt.ylabel("Price",size=15,c="red")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.barplot(data=df,y="Price",x='Name',hue='Transmission')
plt.xlabel("Location",size=15,c="red")
plt.ylabel("Price",size=15,c="red")
plt.xticks(rotation="vertical",size=10)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df[["Price","Kilometers_Driven","Power","Mileage","Engine","Seats","Transmission"]].corr(), annot=True,linewidths=.5,fmt='.1f')
plt.title("Correlation Graph",c="r",size=25)
plt.show()

# %%
df.drop(['Mileage','Seats','Engine','Transmission'],axis=1,inplace=True)

# %%
df['Car_Name'] = df['Name'].astype(str) + " " + df['Car']

# %%
df.drop(['Name','Car'],axis=1,inplace=True)

# %%
len(df['Car_Name'].value_counts()[df['Car_Name'].value_counts()<10])
# Out:
# 522

# %%
df['Car_Name'].value_counts()[df['Car_Name'].value_counts()<10]
# Out:
# Mahindra TUV 300            9
# Toyota Etios GD             9
# Nissan Micra XV             9
# Mitsubishi Pajero 2.8       9
# Audi Q3 35                  9
#                            ..
# Maruti Ritz AT              1
# Skoda Laura Classic         1
# Maruti 1000 AC              1
# Renault Duster Adventure    1
# Tata Tiago Wizz             1
# Name: Car_Name, Length: 522, dtype: int64

# %%
l = df['Car_Name'].value_counts()[df['Car_Name'].value_counts()<10].index
df[df['Car_Name'].isin(l)]
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Owner_Type   Power  Price  \
# 2        Chennai  2011              46000    Petrol      First   88.70   4.50
# 4     Coimbatore  2013              40670    Diesel     Second  140.80  17.74
# 10         Kochi  2018              25692    Petrol      First  103.25   9.95
# 17        Jaipur  2017              25000    Diesel      First   74.00   5.99
# 21     Bangalore  2015              55392    Diesel     Second   88.50   8.25
# ...          ...   ...                ...       ...        ...     ...    ...
# 6008   Hyderabad  2013              40000    Diesel     Second  300.00  45.00
# 6009      Mumbai  2015              33500    Petrol      First  158.20  19.75
# 6010       Delhi  2013              33746    Petrol      First   86.80   3.20
# 6011   Hyderabad  2009              53000    Petrol      First  262.60   4.75
# 6016      Jaipur  2012              55000    Diesel     Second  112.00   2.90
#
#                      Car_Name
# 2                Honda Jazz V
# 4                 Audi A4 New
# 10           Maruti Ciaz Zeta
# 17          Maruti Swift DDiS
# 21             Maruti S Cross
# ...                       ...
# 6008  Porsche Panamera Diesel
# 6009      Toyota Camry Hybrid
# 6010           Honda Brio 1.2
# 6011         Skoda Superb 3.6
# 6016         Mahindra Xylo D4
#
# [1582 rows x 8 columns]

# %%
df = df[['Car_Name','Location','Year','Kilometers_Driven','Fuel_Type','Owner_Type','Power','Price']]

# %%
df
# Out:
#                    Car_Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0            Maruti Wagon R      Mumbai  2010              72000       CNG
# 1         Hyundai Creta 1.6        Pune  2015              41000    Diesel
# 2              Honda Jazz V     Chennai  2011              46000    Petrol
# 3         Maruti Ertiga VDI     Chennai  2012              87000    Diesel
# 4               Audi A4 New  Coimbatore  2013              40670    Diesel
# ...                     ...         ...   ...                ...       ...
# 6014       Maruti Swift VDI       Delhi  2014              27365    Diesel
# 6015      Hyundai Xcent 1.1      Jaipur  2015             100000    Diesel
# 6016       Mahindra Xylo D4      Jaipur  2012              55000    Diesel
# 6017         Maruti Wagon R     Kolkata  2013              46000    Petrol
# 6018  Chevrolet Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Owner_Type   Power  Price
# 0         First   58.16   1.75
# 1         First  126.20  12.50
# 2         First   88.70   4.50
# 3         First   88.76   6.00
# 4        Second  140.80  17.74
# ...         ...     ...    ...
# 6014      First   74.00   4.75
# 6015      First   71.00   4.00
# 6016     Second  112.00   2.90
# 6017      First   67.10   2.65
# 6018      First   57.60   2.50
#
# [5968 rows x 8 columns]

# %%
df.shape
# Out:
# (5968, 8)

# %%
df.dtypes
# Out:
# Car_Name              object
# Location              object
# Year                  object
# Kilometers_Driven      int64
# Fuel_Type             object
# Owner_Type            object
# Power                float64
# Price                float64
# dtype: object

# %%
df[['Car_Name','Location','Year','Owner_Type','Fuel_Type']].nunique()
# Out:
# Car_Name      669
# Location       11
# Year           20
# Owner_Type      3
# Fuel_Type       3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Car_Name             0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Owner_Type           0
# Power                0
# Price                0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
lst = ['Car_Name','Location','Fuel_Type']

# %%
for i in lst:
    le = LabelEncoder()
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Car_Name  Location  Year  Kilometers_Driven  Fuel_Type Owner_Type  \
# 0          410         9  2010              72000          0      First
# 1          181        10  2015              41000          1      First
# 2          168         2  2011              46000          2      First
# 3          353         2  2012              87000          1      First
# 4            6         3  2013              40670          1     Second
# ...        ...       ...   ...                ...        ...        ...
# 6014       399         4  2014              27365          1      First
# 6015       221         6  2015             100000          1      First
# 6016       295         6  2012              55000          1     Second
# 6017       410         8  2013              46000          2      First
# 6018        52         5  2011              47000          1      First
#
#        Power  Price
# 0      58.16   1.75
# 1     126.20  12.50
# 2      88.70   4.50
# 3      88.76   6.00
# 4     140.80  17.74
# ...      ...    ...
# 6014   74.00   4.75
# 6015   71.00   4.00
# 6016  112.00   2.90
# 6017   67.10   2.65
# 6018   57.60   2.50
#
# [5968 rows x 8 columns]

# %%
df['Owner_Type'].value_counts()
# Out:
# First     4896
# Second     962
# Third      110
# Name: Owner_Type, dtype: int64

# %%
dic = {'First':2,'Second':1,'Third':0}

# %%
df['Year'].value_counts()
# Out:
# 2014              793
# 2015              740
# 2016              739
# 2013              645
# 2017              584
# 2012              574
# 2011              462
# 2010              338
# 2018              297
# 2009              196
# 2008              169
# 2007              121
# 2019              102
# 2006               76
# 2005               56
# 2004               29
# 2003               16
# 2002               14
# less than 2001     10
# 2001                7
# Name: Year, dtype: int64

# %%
dic1 = {'2019':19,"2018":18,"2017":17,"2016":16,"2015":15,"2014":14,"2013":13,"2012":12,"2011":11,"2010":10,"2009":9,
        "2008":8,"2007":7,"2006":6,"2005":5,"2004":4,"2003":3,"2002":2,"2001":1,"less than 2001":0 }

# %%
df['Owner_Type']=df['Owner_Type'].map(dic)
df['Year']=df['Year'].map(dic1)

# %%
df
# Out:
#       Car_Name  Location  Year  Kilometers_Driven  Fuel_Type  Owner_Type  \
# 0          410         9    10              72000          0           2
# 1          181        10    15              41000          1           2
# 2          168         2    11              46000          2           2
# 3          353         2    12              87000          1           2
# 4            6         3    13              40670          1           1
# ...        ...       ...   ...                ...        ...         ...
# 6014       399         4    14              27365          1           2
# 6015       221         6    15             100000          1           2
# 6016       295         6    12              55000          1           1
# 6017       410         8    13              46000          2           2
# 6018        52         5    11              47000          1           2
#
#        Power  Price
# 0      58.16   1.75
# 1     126.20  12.50
# 2      88.70   4.50
# 3      88.76   6.00
# 4     140.80  17.74
# ...      ...    ...
# 6014   74.00   4.75
# 6015   71.00   4.00
# 6016  112.00   2.90
# 6017   67.10   2.65
# 6018   57.60   2.50
#
# [5968 rows x 8 columns]

# %%
df['Year'].value_counts()
# Out:
# 14    793
# 15    740
# 16    739
# 13    645
# 17    584
# 12    574
# 11    462
# 10    338
# 18    297
# 9     196
# 8     169
# 7     121
# 19    102
# 6      76
# 5      56
# 4      29
# 3      16
# 2      14
# 0      10
# 1       7
# Name: Year, dtype: int64

# %%
X = df.drop("Price",axis=1)   #X --- > Independent variables
Y= df['Price']                 #Y --- > Dependent variables

# %%
Y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 5968, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#       Car_Name  Location  Year  Kilometers_Driven  Fuel_Type  Owner_Type  \
# 5059       409         3    17              58829          1           2
# 5006       152         7    14              60952          2           2
# 4297       597         9    14              68400          2           2
# 1189       154         2    14              30000          2           1
# 1644       173         9    14              57000          1           2
# ...        ...       ...   ...                ...        ...         ...
# 912        347         3    12              56661          2           2
# 5236       214         2    12              45000          1           2
# 4016       636         9     7              61932          1           1
# 238        228         7    18              14960          2           2
# 5200       506         3    18              38171          2           1
#
#        Power
# 5059   88.50
# 5006  118.00
# 4297  178.40
# 1189  116.30
# 1644   98.60
# ...      ...
# 912    73.00
# 5236  126.32
# 4016  140.00
# 238    81.83
# 5200   67.00
#
# [4177 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100)

# %%
rf.fit(X_train, Y_train)
y_pred= rf.predict(X_test)

# %%
print("Accuracy on Traing set: ",rf.score(X_train,Y_train))
print("Accuracy on Testing set: ",rf.score(X_test,Y_test))
# Out:
# Accuracy on Traing set:  0.9827006963344489
# Accuracy on Testing set:  0.9199862736867801

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("\t\tError Table")
print('Mean Absolute Error      : ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared  Error      : ', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared  Error : ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
print('R Squared Error          : ', metrics.r2_score(Y_test, y_pred))
# Out:
# 		Error Table
# Mean Absolute Error      :  1.4681950740474865
# Mean Squared  Error      :  8.639867150693766
# Root Mean Squared  Error :  2.9393650931270456
# R Squared Error          :  0.9199862736867801
